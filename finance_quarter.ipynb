# %%
import pandas as pd
import numpy as np
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

from datetime import date

# %%
html = urlopen("https://mse.mn/mn/company/458")
soup = BeautifulSoup(html)

# %%
soup.title.text
# Out:
# 'Монголын Хөрөнгийн Бирж - Таван толгой ХК '

# %%
soup.title.text.strip()
# Out:
# 'Монголын Хөрөнгийн Бирж - Таван толгой ХК'

# %%
soup.find_all("div", class_="company_finance_item")
# Out:
# [<div class="company_finance_item" id="company-2023-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>0</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>0</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>0</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>0</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>0</b>
#  </li>
#  <li>Цэвэр ашиг <b>0</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>0</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b></b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b></b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b></b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				0
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				0
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2022-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>0</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>0</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>0</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>0</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>0</b>
#  </li>
#  <li>Цэвэр ашиг <b>0</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>0</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b></b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b></b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b></b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				0
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				0
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2022-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>0</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>0</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>0</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>0</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>0</b>
#  </li>
#  <li>Цэвэр ашиг <b>0</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>0</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b></b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b></b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b></b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				0
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				0
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2021-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>0</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>0</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>0</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>0</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>0</b>
#  </li>
#  <li>Цэвэр ашиг <b>0</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>0</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b></b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b></b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b></b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				0
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				0
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2021-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>0</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>0</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>0</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>0</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>0</b>
#  </li>
#  <li>Цэвэр ашиг <b>0</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>0</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b></b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b></b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b></b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				0
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				0
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2020-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>140,102,360,600</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>64,027,158,600</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>76,075,202,000</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>254,181,245,100 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>210,357,174,600</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>39,972,023,800</b>
#  </li>
#  <li>Цэвэр ашиг <b>31,345,182,600</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,445</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.2237</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.412</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.2853</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				595.1783
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				12.408
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2020-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>105,151,065,500</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>54,948,271,700</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>50,202,793,800</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>91,686,851,900 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>85,836,594,100</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>4,248,462,900</b>
#  </li>
#  <li>Цэвэр ашиг <b>3,912,236,500</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>953</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.0372</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.0779</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.0404</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				74.285
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				75.1834
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2019-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>122,265,515,100</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>32,736,845,700</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>89,528,669,400</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>263,521,783,200 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>201,116,418,300</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>62,663,914,000</b>
#  </li>
#  <li>Цэвэр ашиг <b>48,062,652,700</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,700</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.3931</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.5368</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.5125</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				912.6074
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				7.0731
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2019-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>144,531,117,100</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>77,316,082,600</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>67,215,034,500</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>123,729,621,600 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>92,918,095,600</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>29,945,199,100</b>
#  </li>
#  <li>Цэвэр ашиг <b>23,013,969,300</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,276</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.1592</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.3424</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.2072</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				436.9863
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				15.3437
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2018-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>157,594,846,500</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>67,156,994,000</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>90,437,852,500</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>226,360,600,600 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>159,581,281,300</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>68,680,586,500</b>
#  </li>
#  <li>Цэвэр ашиг <b>52,858,107,900</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,717</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.3354</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.5845</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.4358</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				1003.6629
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				6.6706
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2018-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>145,907,092,400</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>86,626,387,900</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>59,280,704,500</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>90,493,295,100 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>61,148,096,800</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>25,846,342,000</b>
#  </li>
#  <li>Цэвэр ашиг <b>19,256,579,500</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,126</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.132</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.3248</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.1771</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				365.6414
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				21.5648
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2017-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>272,838,804,200</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>105,891,547,200</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>166,947,257,000</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>427,930,350,000 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>233,763,614,600</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>189,378,004,000</b>
#  </li>
#  <li>Цэвэр ашиг <b>141,054,644,100</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>3,170</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.517</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.8449</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.6941</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				2678.3273
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				3.8307
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2017-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>169,888,202,800</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>85,825,887,600</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>84,062,315,200</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>255,013,744,000 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>170,582,183,900</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>77,380,666,900</b>
#  </li>
#  <li>Цэвэр ашиг <b>57,189,842,600</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,596</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.3366</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.6803</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.4555</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				1085.9133
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				6.1009
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2016-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>147,687,060,000</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>68,678,288,800</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>79,008,771,200</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>176,544,410,800 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>108,982,341,200</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>70,073,490,200</b>
#  </li>
#  <li>Цэвэр ашиг <b>54,042,354,900</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,500</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.3659</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.684</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.4745</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				1026.1492
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				4.3756
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2015-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>56,971,118,000</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>28,370,405,300</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>28,600,712,700</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>25,322,855,500 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>22,711,324,200</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>639,209,900</b>
#  </li>
#  <li>Цэвэр ашиг <b>572,070,400</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>543</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.01</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.02</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.0112</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				10.8624
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				128.2406
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2013-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>112,335,058,100</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>17,446,967,900</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>94,888,090,200</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>161,746,953,300 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>78,786,683,800</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>82,176,823,300</b>
#  </li>
#  <li>Цэвэр ашиг <b>62,096,483,900</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,802</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.5528</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.6544</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.7315</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				1179.08
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				4.2406
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2013-2">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>71,291,890,200</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>17,418,753,800</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>53,873,136,400</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>64,294,726,800 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>38,403,760,400</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>25,439,691,400</b>
#  </li>
#  <li>Цэвэр ашиг <b>19,588,854,000</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>1,023</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.2748</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.3636</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.3568</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				371.9506
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				8.3344
#  				    								    			</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2011-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>115,497,928,705</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>5,822,301,203</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>109,675,627,502</b></li>
#  <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>88,055,570,875</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>105,948,974,895</b>
#  </li>
#  <li>Цэвэр ашиг <b>80,057,983,480</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>2,083</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.6932</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.73</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.9173</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				1520.1306
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b></b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2010-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>118,561,917,691</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>18,900,420,980</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>99,661,496,711</b></li>
#  <li>Нийт гаргасан хувьцаа <b>526,652</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>62,965,033,145</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>107,503,757,806</b>
#  </li>
#  <li>Цэвэр ашиг <b>76,525,701,226</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>526,652</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>189,236</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.6454</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.7679</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.9067</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				145306.0109
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b></b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>,
#  <div class="company_finance_item" id="company-2009-4">
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн үзүүлэлт</h2>
#  <ul>
#  <li>Нийт хөрөнгө <b>58,835,211,819</b> </li>
#  <li>Өр төлбөрийн нийт дүн <b>5,918,678,602</b></li>
#  <li>Эзэмшигчдийн өмчийн дүн <b>52,916,533,217</b></li>
#  <li>Нийт гаргасан хувьцаа <b>526,652</b></li>
#  </ul>
#  </div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Орлого үр дүнгийн тайлангийн үзүүлэлт</h2>
#  <ul>
#  <li>
#
#  											Нийт борлуулалтын орлого<b>0 </b>
#  </li>
#  <li>
#
#
#  											Борлуулсан бүтээгдэхүүний өртөг <b>39,939,719,186</b>
#  </li>
#  <!-- BANK START -->
#  <!-- BANK END -->
#  <li>
#
#  											Нийт ашиг <b>55,496,543,483</b>
#  </li>
#  <li>Цэвэр ашиг <b>42,752,748,558</b></li>
#  <li>Ногдол ашиг /энгийн/ <b>0</b></li>
#  <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
#  <li>Нэгж хувьцааны дансны үнэ <b>100,477</b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  <div class="col-lg-6 col-md-6">
#  <h2>Санхүүгийн харьцаанууд</h2>
#  <ul>
#  <li>Нийт хөрөнгийн өгөөж /ROA/ <b>0.7267</b></li>
#  <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b>0.8079</b></li>
#  <li>Нийт хөрөнгийн эргэц /ROTA/ <b>0.9433</b></li>
#  <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				81178.3655
#  				    				</b></li>
#  <li>Үнэ ашгийн харьцаа (P/E Ratio) <b></b></li>
#  </ul>
#  </div>
#  <div class="clearfix"></div>
#  </div>]

# %%
import pandas as df

for row in soup.find_all("div", class_="company_finance_item"):
    col_name = row["id"][8]
    row_data = row.find_all("li")
    dic = {}
    if row_data:
        for el in row_data:
            print(el)
            s = el.text.split()
            print(s)
            str_vals = []
            for c in s:
                if c.isalpha() or '/' in c or ')' in c:
                    str_vals.append(c)
                else:
                    if any(q.isalpha() for q in c):
                        temp = ""
                        for i in range(len(c)):
                            if c[i].isdigit():
                                str_vals.append(c[:i]) 
                                num = c[i:]
                                break
                    else:
                        num = c
            dic[" ".join(str_vals)] = float(num.replace(',',''))
        new_df = pd.DataFrame(dic.values(), index=dic.keys(), columns=[col_name])
        df = pd.concat([new_df, df], axis=1, sort=False)
# Out:
# <li>Нийт хөрөнгө <b>0</b> </li>
# ['Нийт', 'хөрөнгө', '0']
# <li>Өр төлбөрийн нийт дүн <b>0</b></li>
# ['Өр', 'төлбөрийн', 'нийт', 'дүн', '0']
# <li>Эзэмшигчдийн өмчийн дүн <b>0</b></li>
# ['Эзэмшигчдийн', 'өмчийн', 'дүн', '0']
# <li>Нийт гаргасан хувьцаа <b>52,665,200</b></li>
# ['Нийт', 'гаргасан', 'хувьцаа', '52,665,200']
# <li>
#
# 											Нийт борлуулалтын орлого<b>0 </b>
# </li>
# ['Нийт', 'борлуулалтын', 'орлого0']
# <li>
#
#
# 											Борлуулсан бүтээгдэхүүний өртөг <b>0</b>
# </li>
# ['Борлуулсан', 'бүтээгдэхүүний', 'өртөг', '0']
# <li>
#
# 											Нийт ашиг <b>0</b>
# </li>
# ['Нийт', 'ашиг', '0']
# <li>Цэвэр ашиг <b>0</b></li>
# ['Цэвэр', 'ашиг', '0']
# <li>Ногдол ашиг /энгийн/ <b>0</b></li>
# ['Ногдол', 'ашиг', '/энгийн/', '0']
# <li>Ногдол ашиг /давуу эрхийн/ <b>0</b></li>
# ['Ногдол', 'ашиг', '/давуу', 'эрхийн/', '0']
# <li>Нэгж хувьцааны дансны үнэ <b>0</b></li>
# ['Нэгж', 'хувьцааны', 'дансны', 'үнэ', '0']
# <li>Нийт хөрөнгийн өгөөж /ROA/ <b></b></li>
# ['Нийт', 'хөрөнгийн', 'өгөөж', '/ROA/']
# <li>Хувь нийлүүлсэн хөрөнгийн өгөөж /ROE/ <b></b></li>
# ['Хувь', 'нийлүүлсэн', 'хөрөнгийн', 'өгөөж', '/ROE/']
# <li>Нийт хөрөнгийн эргэц /ROTA/ <b></b></li>
# ['Нийт', 'хөрөнгийн', 'эргэц', '/ROTA/']
# <li>Нэгж хувьцааны өгөөж /EPS/ <b>				    								    				0
# 				    				</b></li>
# ['Нэгж', 'хувьцааны', 'өгөөж', '/EPS/', '0']
# <li>Үнэ ашгийн харьцаа (P/E Ratio) <b>				    								    								    				0
# 				    								    			</b></li>
# ['Үнэ', 'ашгийн', 'харьцаа', '(P/E', 'Ratio)', '0']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26584\2131363764.py in <module>
#      26             dic[" ".join(str_vals)] = float(num.replace(',',''))
#      27         new_df = pd.DataFrame(dic.values(), index=dic.keys(), columns=[col_name])
# ---> 28         df = pd.concat([new_df, df], axis=1, sort=False)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     435                     "only Series and DataFrame objs are valid"
#     436                 )
# --> 437                 raise TypeError(msg)
#     438
#     439             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'module'>'; only Series and DataFrame objs are valid

# %%
df
# Out:
# <module 'pandas' from 'c:\\ProgramData\\Anaconda3\\lib\\site-packages\\pandas\\__init__.py'>
